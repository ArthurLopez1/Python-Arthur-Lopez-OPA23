# %% [markdown]
# # Exercise - file handling
#
# ### 0. Dice rolls (*)
# Create a textfile called dice_rolls.txt using Python. Also for each subtask, write adequate headers.
#
#   a)   Simulate 20 dice rolls and write them to your textfile. (*)
#
#   b)   Sort the dice rolls from a) and write them to a separate row in the same textfile. (*)
#
#   c)   Count the number of fours in the dice rolls and write them to a separate row in the same textfile. (*)

# %%
import random as rnd

def roll_dice():
    return rnd.randint(1,6)

with open('dice_rolls.txt', 'w') as file:
    file.write("Dice rolls\n")
    file.write("----------\n")

    rolls = [roll_dice() for _ in range(20)]

    file.write(f"Rolls: {rolls}\n")

with open('dice_rolls.txt', 'a') as file:
    sorted_rolls = sorted(rolls)

    file.write(f"Sorted rolls: {sorted_rolls}\n")

four_rolls = [r for r in sorted_rolls if r == 4]

with open('dice_rolls.txt', 'a') as file:
    file.write(f"Number 4 rolls: {len(four_rolls)}\n")

# %% [markdown]
# 1. Test results (*)
# Read in the file test_result.txt (located in the data folder of this repo) in Python.
#
#   a)   Print out the text in the terminal (*)
#
#   b)   Create new rows in the same file and write the people and their corresponding scores in alphabetical order. (*)
#
#   c)   Create additional rows in the same file and sort the people after their grades. The grade limits are: (**)
#
# F	< 20
# E	20-29
# D	30-39
# C	40-49
# B	50-59
# A	60-70

# %%
with open('test_result.txt', 'r') as file:
    for line in file:
        print(line.strip())

# %%
with open('test_result.txt', 'r') as file:
    lines = file.readlines()

lines.sort()

with open('test_result.txt', 'a') as file:
    file.write("\n\nAlphabetical order:\n\n")
    for line in lines:
        file.write(line)

# %%
# Read the content of the file into a list
with open('test_result.txt', 'r') as file:
    lines = file.readlines()

# Find the index of the line after "Alphabetical order:"
index = lines.index('Alphabetical order:\n') + 1

# Extract lines after "Alphabetical order:"
relevant_lines = lines[index:]

# Create a list of names and grades
names_and_grades = []
for line in relevant_lines:
    parts = line.strip().split()
    if len(parts) >= 3:  # Ensure that each line contains at least three parts (name, last name, grade)
        name = ' '.join(parts[:-1])  # Join all parts except the last one to get the full name
        grade = int(parts[-1])  # Get the last part as the grade
        names_and_grades.append((name, grade))

# Define grade categories
grade_categories = {
    'F': (0, 20),
    'E': (20, 30),
    'D': (30, 40),
    'C': (40, 50),
    'B': (50, 60),
    'A': (60, 71)
}

# Function to determine grade based on score
def determine_grade(score):
    for grade, limits in grade_categories.items():
        if limits[0] <= score < limits[1]:
            return grade
    return 'Unknown'

# Sort names and grades by grade
sorted_names_and_grades = sorted(names_and_grades, key=lambda x: x[1])

# Write the sorted names and grades to a new row in the file
with open('test_result.txt', 'a') as file:
    file.write("\n\nGrades in letters order:\n\n")  # Write a header for the grades order
    for name, grade in sorted_names_and_grades:
        file.write(f"{name}: {determine_grade(grade)}\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[214], line 17
#      15     if len(parts) >= 3:  # Ensure that each line contains at least three parts (name, last name, grade)
#      16         name = ' '.join(parts[:-1])  # Join all parts except the last one to get the full name
# ---> 17         grade = int(parts[-1])  # Get the last part as the grade
#      18         names_and_grades.append((name, grade))
#      20 # Define grade categories
#
# ValueError: invalid literal for int() with base 10: 'order:'

# %% [markdown]
# ### 2. National test (*)
# #### Read in the file NPvt19Ma2A.txt and NPvt19Ma2C.txt (located in the data folder of this repo) in Python. Use matplotlib to plot pie charts for each grade categories in each file.

# %%
import matplotlib.pyplot as plt

def plot_pie_chart(file_path, delimiter=" ", colors=None):

    with open(file_path, 'r') as file:
        lines = file.readlines()

        categories = []
        percentages = []

        for line in lines:
            category, percentage_str = line.strip().split(delimiter)
            categories.append(category)

            percentage = float(percentage_str.strip('%'))
            percentages.append(percentage)

        total_percentage = sum(percentages)
        values = [percentage * total_percentage / 100.0 for percentage in percentages]

    if colors is None:
        colors = ["#54bebe", "#76c8c8", "#98d1d1", "#badbdb", "#dedad2", "#e4bcad", "#df979e", "#d7658b", "#c80064"]    

    plt.figure(figsize=(8,8))
    plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=180, labeldistance=1.1,colors=colors)
    plt.axis('equal')
    plt.title('Grades 1')
    plt.show()

file_path = 'NPvt19Ma2A.txt'
#colors = ["#54bebe", "#76c8c8", "#98d1d1", "#badbdb", "#dedad2", "#e4bcad", "#df979e", "#d7658b", "#c80064"]
colors = ["#fd7f6f", "#7eb0d5", "#b2e061", "#bd7ebe", "#ffb55a", "#ffee65", "#beb9db", "#fdcce5", "#8bd3c7"]

plot_pie_chart(file_path, colors=colors)

# %%
import matplotlib.pyplot as plt

def plot_pie_chart(file_path, delimiter=" ", colors=None):

    with open(file_path, 'r') as file:
        lines = file.readlines()

        categories = []
        percentages = []

        for line in lines:
            category, percentage_str = line.strip().split(delimiter)
            categories.append(category)

            percentage = float(percentage_str.strip('%'))
            percentages.append(percentage)

        total_percentage = sum(percentages)
        values = [percentage * total_percentage / 100.0 for percentage in percentages]

    if colors is None:
        colors = ["#54bebe", "#76c8c8", "#98d1d1", "#badbdb", "#dedad2", "#e4bcad", "#df979e", "#d7658b", "#c80064"]    

    plt.figure(figsize=(8,8))
    plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=180, labeldistance=1.1,colors=colors)
    plt.axis('equal')
    plt.title('Grades 2')
    plt.show()

file_path = 'NPvt19Ma2C.txt'
#colors = ["#54bebe", "#76c8c8", "#98d1d1", "#badbdb", "#dedad2", "#e4bcad", "#df979e", "#d7658b", "#c80064"]
colors = ["#fd7f6f", "#7eb0d5", "#b2e061", "#bd7ebe", "#ffb55a", "#ffee65", "#beb9db", "#fdcce5", "#8bd3c7"]

plot_pie_chart(file_path, colors=colors)
